# %% [markdown]
# # Deep Learning
#
# Ahora entramos a un terreno nuevo, el de las neuronas. Aunque no hablamos de neuronas de forma literal, las utilizamos como concepto de programacion para hacer un modelo de aprendisaje que se comporta como las neuronas, de esta forma estos modelo logran reconocer patrones para despues predecir comportamientos.
#
# En machine learning existe el **Deep Learning**, o aprendizaje profundo, que es un pilar para las inteligencias artificiales. Estas trabajan con redes neuronales que sirven para hacer calculos que recrearan componentes de aprendizaje.

# %% [markdown]
# ## Unidad Lineal como un modelo
#
# Veremos como usar de una forma muy simple una nurona, solo de forma tecnica.

# %%
from tensorflow import keras
from tensorflow.keras import layers

# Creamos una red con una sola unidad
model = keras.Sequential([
    layers.Dense(units = 1, input_shape = [3])
])
# Out:
# C:\Users\CDWLu\miniconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
